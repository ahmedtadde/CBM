# %%
import ujson
import resources
import db
import warnings
warnings.filterwarnings('ignore')
from joblib import Parallel, delayed  
import multiprocessing
num_cores = multiprocessing.cpu_count()

# %%
dc =  resources.get_movies_by_tag('dc')
marvel = resources.get_movies_by_tag('marvel')
other = resources.get_movies_by_tag('other')

# %%
# %%capture
# ========================= DOWNLOAD======================================
marvel = Parallel(n_jobs=num_cores)(delayed(db.collect_data)(movie) for movie in marvel)
dc = Parallel(n_jobs=num_cores)(delayed(db.collect_data)(movie) for movie in dc)
other = Parallel(n_jobs=num_cores)(delayed(db.collect_data)(movie) for movie in other)
# Out:
# [{u'alias': u'amazingspiderman2',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'The Amazing Spider-Man 2'},
#  {u'alias': u'antman',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'Ant-Man'},
#  {u'alias': u'avengers11',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u"Marvel's The Avengers"},
#  {u'alias': u'avengers2',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'Avengers: Age of Ultron'},
#  {u'alias': u'blade',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'Blade'},
#  {u'alias': u'captainamerica',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'Captain America: The First Avenger'},
#  {u'alias': u'daredevil',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'Daredevil'},
#  {u'alias': u'deadpool2016',
#   u'tag': u'marvel',
#   u'timestamp': 1494937615,
#   u'title': u'Deadpool'},
#  {u'alias': u'disney2014',
# ...

# %%
# %%capture
#========================== ADD DOWNLOADS TO DB ===============================================
marvel = Parallel(n_jobs=num_cores)(delayed(db.add_movie)(movie) for movie in marvel)
dc = Parallel(n_jobs=num_cores)(delayed(db.add_movie)(movie) for movie in dc)
other = Parallel(n_jobs=num_cores)(delayed(db.add_movie)(movie) for movie in other)
