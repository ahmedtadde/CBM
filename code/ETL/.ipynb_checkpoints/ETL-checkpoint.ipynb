# %%
import ujson
import resources
import db
import numpy as np
import pandas as pd


import warnings
warnings.filterwarnings('ignore')
from joblib import Parallel, delayed  
import multiprocessing
num_cores = multiprocessing.cpu_count()

# %%
# with open('temp.json','w') as f:
#     ujson.dump(movies,f)

with open('temp.json') as f:
    movies = ujson.load(f)

# %%
metadata = pd.DataFrame([db.metadata(movie) for movie in movies])
metadata = metadata.set_index('imdbID')

# %%
summary = pd.DataFrame([db.summary(movie) for movie in movies])
summary['imdbID'] = metadata.index

# %%
weekly_ranks = pd.DataFrame([db.weekly_ranks(movie) for movie in movies])
weekly_ranks['imdbID'] = metadata.index

# %%
weekly_avgs_per_theater = pd.DataFrame([db.weekly_avgs_per_theater(movie) for movie in movies])
weekly_avgs_per_theater['imdbID'] = metadata.index

# %%
weekly_percent_changes = pd.DataFrame([db.weekly_percent_changes(movie) for movie in movies])
ordered_cols_1_to_9 = [ "week_{}_change".format(k) for k in range(1,10)]
ordered_cols_10_to_15 = ["week_{}_change".format(k) for k in range(10,16)]
ordered_cols = ordered_cols_1_to_9 + ordered_cols_10_to_15
weekly_percent_changes = weekly_percent_changes[ordered_cols]
weekly_percent_changes = weekly_percent_changes.cumprod(axis = 'columns')
weekly_percent_changes['score'] = weekly_percent_changes.average(weights = range(1,16))
weekly_percent_changes['imdbID'] = metadata.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-ee57de876ec0> in <module>()
#       5 weekly_percent_changes = weekly_percent_changes[ordered_cols]
#       6 weekly_percent_changes = weekly_percent_changes.cumprod(axis = 'columns')
# ----> 7 weekly_percent_changes['score'] = weekly_percent_changes.average(weights = range(1,16))
#       8 weekly_percent_changes['imdbID'] = metadata.index
#
# /Users/MotherBox/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'average'

# %%
weekly_percent_changes
# Out:
#      week_1_change  week_2_change  week_3_change  week_4_change  \
# 0              1.0          0.435       0.223155       0.126083
# 1              1.0          0.473       0.276705       0.171557
# 2              1.0          0.466       0.243718       0.142088
# 3              1.0          1.570       1.478940       0.881448
# 4              1.0          0.331       0.130414       0.072901
# 5              1.0          0.400       0.344800       0.203777
# 6              1.0          0.560       0.258160            NaN
# 7              1.0          0.485       0.167810       0.069977
# 8              1.0          0.453       0.058890       0.008892
# 9              1.0          0.727       0.612861       0.419197
# 10             1.0          0.560       0.388080       0.165710
# 11             1.0          0.431       0.221103       0.113426
# 12             1.0          0.233       0.129548       0.095866
# 13             1.0          0.825       0.464475       0.282865
# 14             1.0          0.970       0.556780       0.712678
# 15             1.0          0.678       0.483414       0.300684
# 16             1.0          0.404       0.116352       0.019780
# 17             1.0          0.550       0.316800       0.178358
# 18             1.0          0.429       0.148863       0.052846
# 19             1.0          0.241       0.363910       0.348262
# 20             1.0          0.484       0.304436       0.167744
# 21             1.0          0.501       0.227955       0.139281
# 22             1.0          0.488       0.234240       0.132346
# 23             1.0          0.387       0.198918       0.073202
# 24             1.0         13.050       8.691300       5.840554
# 25             1.0          0.459       0.169371       0.058941
# 26             1.0          0.624       0.426816       0.280845
# 27             1.0          0.537       0.286758       0.084880
# 18              NaN             NaN             NaN  -19.262157  tt1219827
# 19     8.357385e-06    5.657950e-06        0.000003  -93.704329  tt0162346
# 20     1.456406e-03    5.927573e-04             NaN  -54.156330  tt0990407
# 21              NaN             NaN             NaN  -32.410128  tt0448157
# 22              NaN             NaN             NaN  -21.161124  tt0167190
# 23              NaN             NaN             NaN  -49.355504  tt1267297
# 24     5.684666e-03    5.502757e-03        0.002366  -21.967293  tt0399146
# 25              NaN             NaN             NaN  -23.201436  tt1418377
# 26     1.057783e-03    7.393907e-04        0.000493  -58.424131  tt0317705
# 27              NaN             NaN             NaN   -7.845186  tt0108148
# 28              NaN             NaN             NaN  -12.095620  tt0236348
# 29              NaN             NaN             NaN  -40.932139  tt1250777
# ..              ...             ...             ...         ...        ...
# 125    3.961132e-04    2.158817e-04             NaN  -64.045190  tt0770828
# 126             NaN             NaN             NaN  -50.629722  tt2975590
# 127             NaN             NaN             NaN   -8.181352  tt0086393
# 128             NaN             NaN             NaN   -2.243438  tt0094074
# 129             NaN             NaN             NaN  -48.261838  tt1253863
# 130    9.224430e-05             NaN             NaN  -65.809680  tt0758730
# 131             NaN             NaN             NaN    0.000000  tt0115986
# 132             NaN             NaN             NaN  -34.221385  tt0411477
# 133             NaN             NaN             NaN   -4.909317  tt0113492
# 134             NaN             NaN             NaN  -14.730331  tt1650554
# 135             NaN             NaN             NaN  -16.389639  tt0120746
# 136             NaN             NaN             NaN  -17.700978  tt0120912
# 137             NaN             NaN             NaN  -22.270398  tt0458481
# 138             NaN             NaN             NaN  -28.994618  tt0187738
# 139             NaN             NaN             NaN  -34.445981  tt0359013
# 140             NaN             NaN             NaN  -42.984424  tt1502712
# 141    1.247949e-03    8.573409e-04        0.000763  -66.353460  tt0486576
# 142             NaN             NaN             NaN  -59.197055  tt1071875
# 143             NaN             NaN             NaN  -59.147591  tt0800080
# 144    1.100060e-03    7.040382e-04        0.000438  -62.938321  tt1228705
# 145    9.195976e-04    7.494720e-04        0.000192  -64.951767  tt1300854
# 146             NaN             NaN             NaN   -3.911835  tt0450314
# 147    2.502298e-03    1.571443e-03        0.001681  -55.064576  tt0316654
# 148    8.608063e-04    5.139013e-04        0.000296  -66.305375  tt0413300
# 149    1.422777e-03    8.607803e-04             NaN  -55.773740  tt0948470
# 150    1.324739e-03    2.662726e-03        0.002506  -60.283228  tt1981115
# 151    2.908667e-05    1.922629e-05        0.000013  -78.886504  tt1430132
# 152             NaN             NaN             NaN  -34.018056  tt3315342
# 153    9.566254e-04    5.548427e-04        0.001265  -63.132136  tt1877832
# 154    3.414042e-04    3.157989e-04        0.000117  -71.483441  tt1270798
#
# [155 rows x 17 columns]

# %%
import numpy as np
np.cumprod([1,2, 6, np.nan, np.nan])
# Out:
# array([  1.,   2.,  12.,  nan,  nan])

# %%
# !pip install --upgrade pandas
# Out:
# Collecting pandas
#   Downloading pandas-0.20.1-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (15.0MB)
#     100% |████████████████████████████████| 15.0MB 33kB/s eta 0:00:01
# Collecting python-dateutil (from pandas)
#   Downloading python_dateutil-2.6.0-py2.py3-none-any.whl (194kB)
#     100% |████████████████████████████████| 194kB 598kB/s ta 0:00:01
# Requirement already up-to-date: numpy>=1.7.0 in /Users/MotherBox/anaconda/lib/python2.7/site-packages (from pandas)
# Collecting pytz>=2011k (from pandas)
#   Downloading pytz-2017.2-py2.py3-none-any.whl (484kB)
#     100% |████████████████████████████████| 491kB 423kB/s ta 0:00:01
# Requirement already up-to-date: six>=1.5 in /Users/MotherBox/anaconda/lib/python2.7/site-packages (from python-dateutil->pandas)
# Installing collected packages: python-dateutil, pytz, pandas
#   Found existing installation: python-dateutil 2.5.1
#     Uninstalling python-dateutil-2.5.1:
#       Successfully uninstalled python-dateutil-2.5.1
#   Found existing installation: pytz 2016.2
#     DEPRECATION: Uninstalling a distutils installed project (pytz) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling pytz-2016.2:
#       Successfully uninstalled pytz-2016.2
#   Found existing installation: pandas 0.18.0
#     Uninstalling pandas-0.18.0:
#       Successfully uninstalled pandas-0.18.0
# Successfully installed pandas-0.20.1 python-dateutil-2.6.0 pytz-2017.2

# %%
# %%capture
# ## ========================= INSERT NEW MOVIE(S) TO RESOURCES ======================================
# movies = []
# inserted = Parallel(n_jobs=num_cores)(delayed(resources.add_to_resources)(movie) for movie in movies)
# del movies

# %%
# %%capture
# ## ========================= UPDATE MOVIE(S) IN RESOURCES ======================================
# movies = []
# updated = Parallel(n_jobs=num_cores)(delayed(resources.update_in_resources)(movie) for movie in movies)
# del movies

# %%
# %%capture
# ## ========================= REMOVE MOVIE(S) FROM RESOURCES ======================================
# movies = []
# deleted = Parallel(n_jobs=num_cores)(delayed(resources.delete_from_resources)(movie) for movie in movies)
# del movies

# %%
# %%capture
# ## ========================= FETCHING DATA FOR ALL MOVIES IN RESOURCES ======================================
# movies = Parallel(n_jobs=num_cores)(delayed(db.collect_data)(movie) for movie in resources.get_all_movies())

# %%
# %%capture
# ## ========================= FETCHING DATA FOR A LIST OF MOVIES IN RESOURCES ======================================
# ## BY TAG (i.e "dc" or 'marvel, or 'other')
# tag_selection = ''
# movies_list = resources.get_movies_by_tag(tag)


# ## BY ALIASES
# selection = []
# movies_list = Parallel(n_jobs=num_cores)(delayed(resources.get_movie_by_alias())(movie) for movie in selection)

# ##---------or

# ## BY TITLE
# selection = []
# movies_list = Parallel(n_jobs=num_cores)(delayed(resources.get_movie_by_title())(movie) for movie in selection)



# movies = Parallel(n_jobs=num_cores)(delayed(db.collect_data)(movie) for movie in movies_list)
# del selection
# del movies_list

# %%
# %%capture
##========================== INSERT NEW MOVIE(S) INTO DB ===============================================
# inserted = Parallel(n_jobs=num_cores)(delayed(db.add_movie)(movie) for movie in movies)
#inserted = [db.add_movie(movie) for movie in movies]

# %%
# %%capture
# ##========================== UPDATE MOVIE(S) INTO DB ===============================================
# updated = Parallel(n_jobs=num_cores)(delayed(db.update_movie)(movie) for movie in movies)
